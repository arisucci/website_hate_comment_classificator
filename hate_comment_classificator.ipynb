# %%
import pandas as pd 
import numpy as np 
from sklearn.model_selection import train_test_split 
from sklearn.feature_extraction.text 
import CountVectorizer from sklearn.tree 
import DecisionTreeClassifier 
import nltk 
import re 
from nltk.corpus import stopwords

# %%
nltk.download('stopwords') stopword= set(stopwords.words('english'))

# %%
from google.colab import drive drive.mount('/gdrive'

# %%
mport os 
os.chdir('/gdrive/MyDrive/Progetto_IL/') 
df = pd.read_csv('COMBINED.csv', encoding='latin-1')

# %%
print(df.head())

# %%
def clean(text): 
text = str(text).lower() text = re.sub('[?]', '', text) 
text = re.sub('https?://\S+|www.\S+', '', text) 
text = re.sub('<.?>+', '', text) 
text = re.sub(r' [^\w\s]', '', text)
text = re.sub('\n', '', text)
text = re.sub('w\d\w', '', text)
text = [word for word in text.split(' ') if word not in stopword] 
text = " ".join(text) 
return text

# %%
df["Cleaned_Comment"] = df["Comment"].apply(clean)

# %%
x-np.array(df "Comment")
yonp.array(df["Label"])

# %%
cv-CountVectorizer()

# %%
df ["Comment"].fillne("", inplace true)

# %%
xcv.fit transfors(df["Coerent"])

# %%
X_train, K_test, y_train, y test train_test_split(X,y, test size 31, random stated)

# %%
model = DecisionTreeClassifier() #classificatere bassto su alberi decisionali

# %%
model.fit(X_train, y train)

# %%
y pred-model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score #utilizzata per calcolare l'accuratezza delle previsioni rispetto alle
print (accuracy_score(y_test,y_pred)) #stamperà l'accuratezza delle previsioni sul set di test
